# %%
import pandas as pd

lang1 = "en"
lang2 = "ja"
path = f"datasets/{lang1}-{lang2}.csv"
df = pd.read_csv(path)
df.head()
# Out:
#                                                   en  \
# 0                      "THE CABINET OF DR. CALIGARI"
# 1                                              Act 1
# 2  "Spirits surround us on every side - they have...
# 3                               "She is my bride..."
# 4  "What she and I have experienced is yet more r...
#
#                           ja
# 0                  カリガリ博士の小屋
# 1                         幕１
# 2  私は亡霊のおかげで家族や家庭を捨てざるをえなかった
# 3                     僕の婚約者だ
# 4      僕と彼女の体験はあなたの物語よりも恐ろしい

# %%
df[lang1].str.len().hist(bins=200, range=(0, 200))
# Out:
# <Axes: >

# %%
df[lang2].str.len().hist(bins=200, range=(0, 200))
# Out:
# <Axes: >

# %%
src_len = df[lang1].str.len()
tgt_len = df[lang2].str.len()
# take the mean of the ratio between tgt-src
mean_len = (tgt_len / src_len).mean()
mean_len
# Out:
# 0.45270955803303853

# %%
# non-weighted:
comp_rate = 0.5
_df = df[df[lang2].str.len() < comp_rate * df[lang1].str.len()]
print(_df.shape)
_df[lang2].str.len().hist(bins=200, range=(0, 200))
# Out:
# (1063367, 2)
# <Axes: >

# %%
comp_rate = 1.0
_df = df[df[lang2].str.len() < mean_len * comp_rate * df[lang1].str.len()]
print(_df.shape)
_df[lang2].str.len().hist(bins=200, range=(0, 200))
# Out:
# (969678, 2)
# <Axes: >
